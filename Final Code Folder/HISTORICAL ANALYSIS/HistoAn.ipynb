# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('MVP_Candidates.csv')

# %%
lebron = df[(df['Player'] == 'LeBron James')].reset_index(drop=True)
lebron = lebron.sort_values('MVP Share', ascending=False)
lebron = lebron.iloc[0:6].reset_index(drop=True)
lebron
# Out:
#          Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  LeBron James  PF       4   28  MIA  76  76     1  0.804878  2877  ...
# 1  LeBron James  SF       3   25  CLE  76  76     1  0.743902  2966  ...
# 2  LeBron James  SF       3   24  CLE  81  81     1  0.804878  3054  ...
# 3  LeBron James  SF       3   27  MIA  62  62     4  0.696970  2326  ...
# 4  LeBron James  PG       1   35  LAL  67  67     3  0.732394  2316  ...
# 5  LeBron James  PF       4   33  CLE  82  82     6  0.609756  3026  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     121    100    120     146     77.0     288.7     336.6    1      0.998
# 1     109    101    111     168    114.0     134.8     229.4    1      0.980
# 2     106    101    109     155    106.0      97.7     182.8    1      0.969
# 3     114    102    115     156     56.0     156.7     217.8    1      0.888
# 4     104     90    102     112     85.0      55.9      37.0    0      0.746
# 5     113     95    112     133     76.0     216.1     233.7    0      0.731
#
#       Year
# 0  2012-13
# 1  2009-10
# 2  2008-09
# 3  2011-12
# 4  2019-20
# 5  2017-18
#
# [6 rows x 119 columns]

# %%
jordan = df[(df['Player'] == 'Michael Jordan')].reset_index(drop=True)
jordan = jordan.sort_values('MVP Share', ascending=False)
jordan = jordan.iloc[0:6].reset_index(drop=True)
jordan
# Out:
#            Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Michael Jordan  SG       2   32  CHI  82  82     1  0.878049  3090  ...
# 1  Michael Jordan  SG       2   28  CHI  80  80     1  0.817073  3102  ...
# 2  Michael Jordan  SG       2   34  CHI  82  82     1  0.756098  3181  ...
# 3  Michael Jordan  SG       2   27  CHI  82  82     2  0.743902  3034  ...
# 4  Michael Jordan  SG       2   33  CHI  82  82     1  0.841463  3106  ...
# 5  Michael Jordan  SG       2   29  CHI  78  78     3  0.695122  3067  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     105    113    107     108     70.0      97.7     172.3    1      0.986
# 1     108    110    109     106     63.0     142.6     196.0    1      0.938
# 2      99    106    102     116     42.0     -17.9      42.5    1      0.934
# 3     112    111    113     114     62.0     218.6     301.1    1      0.928
# 4     105    113    106      95     74.0      85.7     132.8    0      0.832
# 5     105    111    105      88    110.0      99.0     124.1    0      0.577
#
#       Year
# 0  1995-96
# 1  1991-92
# 2  1997-98
# 3  1990-91
# 4  1996-97
# 5  1992-93
#
# [6 rows x 119 columns]

# %%
steph = df[(df['Player'] == 'Stephen Curry')].reset_index(drop=True)
steph = steph.sort_values('MVP Share', ascending=False)
steph = steph.iloc[0:6].reset_index(drop=True)
steph
# Out:
#           Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Stephen Curry  PG       1   27  GSW  79  79     1  0.890244  2700  ...
# 1  Stephen Curry  PG       1   26  GSW  80  80     1  0.817073  2613  ...
# 2  Stephen Curry  PG       1   32  GSW  63  63    14  0.541667  2152  ...
# 3  Stephen Curry  PG       1   30  GSW  69  69     3  0.695122  2331  ...
# 4  Stephen Curry  PG       1   25  GSW  78  78     8  0.621951  2846  ...
# 5  Stephen Curry  PG       1   28  GSW  79  79     1  0.817073  2638  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     125    120    124      91    195.0     406.1     454.7    1      1.000
# 1     120    122    119      92    180.0     262.1     308.9    1      0.922
# 2     113    118    115     117    150.0     184.5     255.3    0      0.449
# 3     115    120    115      83    168.0     213.1     239.9    0      0.173
# 4     113    117    113      89    171.0     179.0     211.3    0      0.053
# 5     113    116    113      93    173.0     191.5     228.9    0      0.051
#
#       Year
# 0  2015-16
# 1  2014-15
# 2  2020-21
# 3  2018-19
# 4  2013-14
# 5  2016-17
#
# [6 rows x 119 columns]

# %%
jokic = df[(df['Player'] == 'Nikola Jokić')].reset_index(drop=True)
jokic = jokic.sort_values('MVP Share', ascending=False).reset_index(drop=True)
jokic
# Out:
#          Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Nikola Jokić   C       5   25  DEN  72  72     5  0.652778  2488  ...
# 1  Nikola Jokić   C       5   26  DEN  74  74    10  0.585366  2476  ...
# 2  Nikola Jokić   C       5   23  DEN  80  80     4  0.658537  2504  ...
# 3  Nikola Jokić   C       5   24  DEN  73  73     6  0.630137  2336  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     112    112    113     123     47.0     164.9     221.1    1      0.961
# 1     117    105    117     144     55.0     230.9     286.9    1      0.875
# 2     104    107    105     113     62.0      50.6      80.9    0      0.210
# 3     107    106    107     108     62.0      77.3      96.8    0      0.018
#
#       Year
# 0  2020-21
# 1  2021-22
# 2  2018-19
# 3  2019-20
#
# [4 rows x 119 columns]

# %%
giannis = df[(df['Player'] == 'Giannis Antetokounmpo')].reset_index(drop=True)
giannis = giannis.sort_values('MVP Share', ascending=False).reset_index(drop=True)
giannis
# Out:
#                   Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  \
# 0  Giannis Antetokounmpo  PF       4   25  MIL  63  63     1  0.767123  1917
# 1  Giannis Antetokounmpo  PF       4   24  MIL  72  72     1  0.731707  2358
# 2  Giannis Antetokounmpo  PF       4   27  MIL  67  67     7  0.621951  2204
# 3  Giannis Antetokounmpo  PF       4   26  MIL  61  61     7  0.638889  2013
# 4  Giannis Antetokounmpo  PF       4   23  MIL  75  75    16  0.536585  2756
# 5  Giannis Antetokounmpo  SF       3   22  MIL  80  80    14  0.512195  2845
#
#    ...  6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  \
# 0  ...     111     82    109     195     62.0     149.6     146.2    1
# 1  ...     114     95    115     213     45.0     186.6     260.5    1
# 2  ...     109     93    112     248     49.0     125.1     211.1    0
# 3  ...     111     88    111     214     51.0     135.6     166.7    0
# 4  ...     104     99    108     182     30.0      65.6     140.9    0
# 5  ...     105    100    109     180     45.0      67.5     143.7    0
#
#    MVP Share     Year
# 0      0.952  2019-20
# 1      0.932  2018-19
# 2      0.595  2021-22
# 3      0.345  2020-21
# 4      0.074  2017-18
# 5      0.007  2016-17
#
# [6 rows x 119 columns]

# %%
harden = df[(df['Player'] == 'James Harden')].reset_index(drop=True)
harden = harden.sort_values('MVP Share', ascending=False).reset_index(drop=True)
harden = harden.iloc[0:6]
harden
# Out:
#          Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  James Harden  SG       2   28  HOU  72  72     1  0.792683  2551  ...
# 1  James Harden  PG       1   29  HOU  78  78     5  0.646341  2867  ...
# 2  James Harden  PG       1   27  HOU  81  81     3  0.670732  2947  ...
# 3  James Harden  SG       2   25  HOU  81  81     3  0.682927  2981  ...
# 4  James Harden  SG       2   30  HOU  68  68     8  0.611111  2483  ...
# 5  James Harden  SG       2   24  HOU  73  73     5  0.658537  2777  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     104    112    111     199    148.0      56.6     223.5    1      0.955
# 1     103    115    110     174    150.0      62.6     258.9    0      0.768
# 2     102    110    111     212    156.0      35.0     234.2    0      0.746
# 3     103    116    113     205    141.0      44.1     259.2    0      0.720
# 4     103    112    111     203    145.0      41.7     227.5    0      0.363
# 5     106    115    114     194    154.0      67.4     231.0    0      0.068
#
#       Year
# 0  2017-18
# 1  2018-19
# 2  2016-17
# 3  2014-15
# 4  2019-20
# 5  2013-14
#
# [6 rows x 119 columns]

# %%
kd = df[(df['Player'] == 'Kevin Durant')].reset_index(drop=True)
kd = kd.sort_values('MVP Share', ascending=False).reset_index(drop=True)
kd = kd.iloc[0:6]
kd
# Out:
#          Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Kevin Durant  SF       3   25  OKC  81  81     2  0.719512  3122  ...
# 1  Kevin Durant  SF       3   23  OKC  66  66     3  0.712121  2546  ...
# 2  Kevin Durant  SF       3   24  OKC  81  81     2  0.731707  3119  ...
# 3  Kevin Durant  SF       3   21  OKC  82  82    10  0.609756  3239  ...
# 4  Kevin Durant  SF       3   22  OKC  78  78     7  0.670732  3038  ...
# 5  Kevin Durant  SF       3   27  OKC  72  72     5  0.670732  2578  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     112    116    117     168    112.0     198.4     383.9    1      0.986
# 1     112    114    116     140    117.0     155.0     250.3    0      0.735
# 2     113    120    121     193     96.0     178.2     394.9    0      0.632
# 3     103    119    112     168     95.0      45.6     259.4    0      0.495
# 4     102    115    109     146    121.0      34.0     174.0    0      0.157
# 5     114    119    117     131    122.0     194.1     297.0    0      0.112
#
#       Year
# 0  2013-14
# 1  2011-12
# 2  2012-13
# 3  2009-10
# 4  2010-11
# 5  2015-16
#
# [6 rows x 119 columns]

# %%
dataframes = [jordan, lebron, steph, kd, harden, giannis, jokic]
dataframes2 = [jordan, lebron, steph, kd, harden, giannis]

# %%
# 1995-96
d9596 = pd.concat([df.iloc[[0]] for df in dataframes]).reset_index(drop=True)

# 1991-92
d9192 = pd.concat([df.iloc[[1]] for df in dataframes]).reset_index(drop=True)

# 1997-98
d9798 = pd.concat([df.iloc[[2]] for df in dataframes]).reset_index(drop=True)

# 1990-91
d9091 = pd.concat([df.iloc[[3]] for df in dataframes]).reset_index(drop=True)

# 1996-97
d9697 = pd.concat([df.iloc[[4]] for df in dataframes2]).reset_index(drop=True)

# 1992-93
d9293 = pd.concat([df.iloc[[5]] for df in dataframes2]).reset_index(drop=True)

d = {'1990-91':d9091, '1991-92':d9192, '1992-93':d9293, '1995-96':d9596, '1996-97':d9697, '1997-98':d9798}

# %%
d9596
# Out:
#                   Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  \
# 0         Michael Jordan  SG       2   32  CHI  82  82     1  0.878049  3090
# 1           LeBron James  PF       4   28  MIA  76  76     1  0.804878  2877
# 2          Stephen Curry  PG       1   27  GSW  79  79     1  0.890244  2700
# 3           Kevin Durant  SF       3   25  OKC  81  81     2  0.719512  3122
# 4           James Harden  SG       2   28  HOU  72  72     1  0.792683  2551
# 5  Giannis Antetokounmpo  PF       4   25  MIL  63  63     1  0.767123  1917
# 6           Nikola Jokić   C       5   25  DEN  72  72     5  0.652778  2488
#
#    ...  6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  \
# 0  ...     105    113    107     108     70.0      97.7     172.3    1
# 1  ...     121    100    120     146     77.0     288.7     336.6    1
# 2  ...     125    120    124      91    195.0     406.1     454.7    1
# 3  ...     112    116    117     168    112.0     198.4     383.9    1
# 4  ...     104    112    111     199    148.0      56.6     223.5    1
# 5  ...     111     82    109     195     62.0     149.6     146.2    1
# 6  ...     112    112    113     123     47.0     164.9     221.1    1
#
#    MVP Share     Year
# 0      0.986  1995-96
# 1      0.998  2012-13
# 2      1.000  2015-16
# 3      0.986  2013-14
# 4      0.955  2017-18
# 5      0.952  2019-20
# 6      0.961  2020-21
#
# [7 rows x 119 columns]

# %%
leagueavs = pd.read_csv('LeagueAveragesByYear.csv')

# %%
# adj_stat = stat_per100 * (no_of_poss / 100) * (MPG / 48)
# MPG - 28th column - index = 27
# Per Game Stats - 28, 29, 31, 32, 34, 35, 38, 39, 41, 42, 43, 44, 45, 46, 47, 48, 49
# Per 100 Stats -  67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83

# %%
'''
1990-91 : 97.8 possessions/48
1991-92 : 96.6 possessions/48
1992-93 : 96.8 possessions/48
1995-96 : 91.8 possessions/48
1996-97 : 90.1 possessions/48
1997-98 : 90.3 possessions/48
'''
# Out:
# '\n1990-91 : 97.8 possessions/48\n1991-92 : 96.6 possessions/48\n1992-93 : 96.8 possessions/48\n1995-96 : 91.8 possessions/48\n1996-97 : 90.1 possessions/48\n1997-98 : 90.3 possessions/48\n'

# %%
seasons = ['1990-91', '1991-92', '1992-93', '1995-96', '1996-97', '1997-98']

# %%
d2 = {'1990-91':None, '1991-92':None, '1992-93':None, '1995-96':None, '1996-97':None, '1997-98':None}

# %%
d['1990-91']
# Out:
#                   Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  \
# 0         Michael Jordan  SG       2   27  CHI  82  82     2  0.743902  3034
# 1           LeBron James  SF       3   27  MIA  62  62     4  0.696970  2326
# 2          Stephen Curry  PG       1   30  GSW  69  69     3  0.695122  2331
# 3           Kevin Durant  SF       3   21  OKC  82  82    10  0.609756  3239
# 4           James Harden  SG       2   25  HOU  81  81     3  0.682927  2981
# 5  Giannis Antetokounmpo  PF       4   26  MIL  61  61     7  0.638889  2013
# 6           Nikola Jokić   C       5   24  DEN  73  73     6  0.630137  2336
#
#    ...  6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  \
# 0  ...     112    111    113     114     62.0     218.6     301.1    1
# 1  ...     114    102    115     156     56.0     156.7     217.8    1
# 2  ...     115    120    115      83    168.0     213.1     239.9    0
# 3  ...     103    119    112     168     95.0      45.6     259.4    0
# 4  ...     103    116    113     205    141.0      44.1     259.2    0
# 5  ...     111     88    111     214     51.0     135.6     166.7    0
# 6  ...     107    106    107     108     62.0      77.3      96.8    0
#
#    MVP Share     Year
# 0      0.928  1990-91
# 1      0.888  2011-12
# 2      0.173  2018-19
# 3      0.495  2009-10
# 4      0.720  2014-15
# 5      0.345  2020-21
# 6      0.018  2019-20
#
# [7 rows x 119 columns]

# %%
for season in seasons:
    yearavs = leagueavs[(leagueavs['Season'] == season)].reset_index(drop=True)
    possper48 = yearavs['Pace']
    dseason = d[season]
    mult_factor = possper48 / (48 * 100)
    for i in dseason.index:
        mf = dseason['2.MP'][i] * mult_factor
        dseason['2.FG'][i] = mf * dseason['4.FG'][i]
        dseason['2.FGA'][i] = mf * dseason['4.FGA'][i]
        dseason['2.3P'][i] = mf * dseason['4.3P'][i]
        dseason['2.3PA'][i] = mf * dseason['4.3PA'][i]
        dseason['2.2P'][i] = mf * dseason['4.2P'][i]
        dseason['2.2PA'][i] = mf * dseason['4.2PA'][i]
        dseason['2.FT'][i] = mf * dseason['4.FT'][i]
        dseason['2.FTA'][i] = mf * dseason['4.FTA'][i]
        dseason['2.ORB'][i] = mf * dseason['4.ORB'][i]
        dseason['2.DRB'][i] = mf * dseason['4.DRB'][i]
        dseason['2.TRB'][i] = mf * dseason['4.TRB'][i]
        dseason['2.AST'][i] = mf * dseason['4.AST'][i]
        dseason['2.STL'][i] = mf * dseason['4.STL'][i]
        dseason['2.BLK'][i] = mf * dseason['4.BLK'][i]
        dseason['2.TOV'][i] = mf * dseason['4.TOV'][i]
        dseason['2.PF'][i] = mf * dseason['4.PF'][i]
        dseason['2.PTS'][i] = mf * dseason['4.PTS'][i]

        dseason['1.FG'][i] = dseason['G'][i] * dseason['2.FG'][i]
        dseason['1.FGA'][i] = dseason['G'][i] * dseason['2.FGA'][i]
        dseason['1.3P'][i] = dseason['G'][i] * dseason['2.3P'][i]
        dseason['1.3PA'][i] = dseason['G'][i] * dseason['2.3PA'][i]
        dseason['1.2P'][i] = dseason['G'][i] * dseason['2.2P'][i]
        dseason['1.2PA'][i] = dseason['G'][i] * dseason['2.2PA'][i]
        dseason['1.FT'][i] = dseason['G'][i] * dseason['2.FT'][i]
        dseason['1.FTA'][i] = dseason['G'][i] * dseason['2.FTA'][i]
        dseason['1.ORB'][i] = dseason['G'][i] * dseason['2.ORB'][i]
        dseason['1.DRB'][i] = dseason['G'][i] * dseason['2.DRB'][i]
        dseason['1.TRB'][i] = dseason['G'][i] * dseason['2.TRB'][i]
        dseason['1.AST'][i] = dseason['G'][i] * dseason['2.AST'][i]
        dseason['1.STL'][i] = dseason['G'][i] * dseason['2.STL'][i]
        dseason['1.BLK'][i] = dseason['G'][i] * dseason['2.BLK'][i]
        dseason['1.TOV'][i] = dseason['G'][i] * dseason['2.TOV'][i]
        dseason['1.PF'][i] = dseason['G'][i] * dseason['2.PF'][i]
        dseason['1.PTS'][i] = dseason['G'][i] * dseason['2.PTS'][i]


'''
    dseasonplayers = []
    for i in range(len(dseason)):
        dseasonplayers.append(dseason[i])
    dfp = pd.concat(dseasonplayers, ignore_index=True)
    d2[season] = dfp
'''
# Out:
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.FG'][i] = mf * dseason['4.FG'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.FGA'][i] = mf * dseason['4.FGA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.3P'][i] = mf * dseason['4.3P'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.3PA'][i] = mf * dseason['4.3PA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.2P'][i] = mf * dseason['4.2P'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.2PA'][i] = mf * dseason['4.2PA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.FT'][i] = mf * dseason['4.FT'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.FTA'][i] = mf * dseason['4.FTA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.ORB'][i] = mf * dseason['4.ORB'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.DRB'][i] = mf * dseason['4.DRB'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.TRB'][i] = mf * dseason['4.TRB'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.AST'][i] = mf * dseason['4.AST'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.STL'][i] = mf * dseason['4.STL'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.BLK'][i] = mf * dseason['4.BLK'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.TOV'][i] = mf * dseason['4.TOV'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.PF'][i] = mf * dseason['4.PF'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.PTS'][i] = mf * dseason['4.PTS'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.FG'][i] = dseason['G'][i] * dseason['2.FG'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.FGA'][i] = dseason['G'][i] * dseason['2.FGA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.3P'][i] = dseason['G'][i] * dseason['2.3P'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.3PA'][i] = dseason['G'][i] * dseason['2.3PA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.2P'][i] = dseason['G'][i] * dseason['2.2P'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.2PA'][i] = dseason['G'][i] * dseason['2.2PA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.FT'][i] = dseason['G'][i] * dseason['2.FT'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.FTA'][i] = dseason['G'][i] * dseason['2.FTA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.ORB'][i] = dseason['G'][i] * dseason['2.ORB'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.DRB'][i] = dseason['G'][i] * dseason['2.DRB'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.TRB'][i] = dseason['G'][i] * dseason['2.TRB'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.AST'][i] = dseason['G'][i] * dseason['2.AST'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.STL'][i] = dseason['G'][i] * dseason['2.STL'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.BLK'][i] = dseason['G'][i] * dseason['2.BLK'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.TOV'][i] = dseason['G'][i] * dseason['2.TOV'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.PF'][i] = dseason['G'][i] * dseason['2.PF'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_10500\3716390129.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['1.PTS'][i] = dseason['G'][i] * dseason['2.PTS'][i]
# '\n    dseasonplayers = []\n    for i in range(len(dseason)):\n        dseasonplayers.append(dseason[i])\n    dfp = pd.concat(dseasonplayers, ignore_index=True)\n    d2[season] = dfp\n'

# %%
histo_test = pd.DataFrame()
for i in d.values():
    histo_test = pd.concat([histo_test, i], ignore_index=True)

# %%
histo_test
# Out:
#                    Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  \
# 0          Michael Jordan  SG       2   27  CHI  82  82     2  0.743902  3034
# 1            LeBron James  SF       3   27  MIA  62  62     4  0.696970  2326
# 2           Stephen Curry  PG       1   30  GSW  69  69     3  0.695122  2331
# 3            Kevin Durant  SF       3   21  OKC  82  82    10  0.609756  3239
# 4            James Harden  SG       2   25  HOU  81  81     3  0.682927  2981
# 5   Giannis Antetokounmpo  PF       4   26  MIL  61  61     7  0.638889  2013
# 6            Nikola Jokić   C       5   24  DEN  73  73     6  0.630137  2336
# 7          Michael Jordan  SG       2   28  CHI  80  80     1  0.817073  3102
# 8            LeBron James  SF       3   25  CLE  76  76     1  0.743902  2966
# 9           Stephen Curry  PG       1   26  GSW  80  80     1  0.817073  2613
# 10           Kevin Durant  SF       3   23  OKC  66  66     3  0.712121  2546
# 11           James Harden  PG       1   29  HOU  78  78     5  0.646341  2867
# 12  Giannis Antetokounmpo  PF       4   24  MIL  72  72     1  0.731707  2358
# 13           Nikola Jokić   C       5   26  DEN  74  74    10  0.585366  2476
# 14         Michael Jordan  SG       2   29  CHI  78  78     3  0.695122  3067
# 15           LeBron James  PF       4   33  CLE  82  82     6  0.609756  3026
# 16          Stephen Curry  PG       1   28  GSW  79  79     1  0.817073  2638
# 17           Kevin Durant  SF       3   27  OKC  72  72     5  0.670732  2578
# 18           James Harden  SG       2   24  HOU  73  73     5  0.658537  2777
# 19  Giannis Antetokounmpo  SF       3   22  MIL  80  80    14  0.512195  2845
# 20         Michael Jordan  SG       2   32  CHI  82  82     1  0.878049  3090
# 21           LeBron James  PF       4   28  MIA  76  76     1  0.804878  2877
# 22          Stephen Curry  PG       1   27  GSW  79  79     1  0.890244  2700
# 23           Kevin Durant  SF       3   25  OKC  81  81     2  0.719512  3122
# 24           James Harden  SG       2   28  HOU  72  72     1  0.792683  2551
# 25  Giannis Antetokounmpo  PF       4   25  MIL  63  63     1  0.767123  1917
# 26           Nikola Jokić   C       5   25  DEN  72  72     5  0.652778  2488
# 27         Michael Jordan  SG       2   33  CHI  82  82     1  0.841463  3106
# 28           LeBron James  PG       1   35  LAL  67  67     3  0.732394  2316
# 29          Stephen Curry  PG       1   25  GSW  78  78     8  0.621951  2846
# 30           Kevin Durant  SF       3   22  OKC  78  78     7  0.670732  3038
# 31           James Harden  SG       2   30  HOU  68  68     8  0.611111  2483
# 32  Giannis Antetokounmpo  PF       4   23  MIL  75  75    16  0.536585  2756
# 33         Michael Jordan  SG       2   34  CHI  82  82     1  0.756098  3181
# 34           LeBron James  SF       3   24  CLE  81  81     1  0.804878  3054
# 35          Stephen Curry  PG       1   32  GSW  63  63    14  0.541667  2152
# 36           Kevin Durant  SF       3   24  OKC  81  81     2  0.731707  3119
# 37           James Harden  PG       1   27  HOU  81  81     3  0.670732  2947
# 38  Giannis Antetokounmpo  PF       4   27  MIL  67  67     7  0.621951  2204
# 39           Nikola Jokić   C       5   23  DEN  80  80     4  0.658537  2504
#
#     ...  6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  \
# 0   ...     112    111    113     114     62.0     218.6     301.1    1
# 1   ...     114    102    115     156     56.0     156.7     217.8    1
# 2   ...     115    120    115      83    168.0     213.1     239.9    0
# 3   ...     103    119    112     168     95.0      45.6     259.4    0
# 4   ...     103    116    113     205    141.0      44.1     259.2    0
# 5   ...     111     88    111     214     51.0     135.6     166.7    0
# 6   ...     107    106    107     108     62.0      77.3      96.8    0
# 7   ...     108    110    109     106     63.0     142.6     196.0    1
# 8   ...     109    101    111     168    114.0     134.8     229.4    1
# 9   ...     120    122    119      92    180.0     262.1     308.9    1
# 10  ...     112    114    116     140    117.0     155.0     250.3    0
# 11  ...     103    115    110     174    150.0      62.6     258.9    0
# 12  ...     114     95    115     213     45.0     186.6     260.5    1
# 13  ...     117    105    117     144     55.0     230.9     286.9    1
# 14  ...     105    111    105      88    110.0      99.0     124.1    0
# 15  ...     113     95    112     133     76.0     216.1     233.7    0
# 16  ...     113    116    113      93    173.0     191.5     228.9    0
# 17  ...     114    119    117     131    122.0     194.1     297.0    0
# 18  ...     106    115    114     194    154.0      67.4     231.0    0
# 19  ...     105    100    109     180     45.0      67.5     143.7    0
# 20  ...     105    113    107     108     70.0      97.7     172.3    1
# 21  ...     121    100    120     146     77.0     288.7     336.6    1
# 22  ...     125    120    124      91    195.0     406.1     454.7    1
# 23  ...     112    116    117     168    112.0     198.4     383.9    1
# 24  ...     104    112    111     199    148.0      56.6     223.5    1
# 25  ...     111     82    109     195     62.0     149.6     146.2    1
# 26  ...     112    112    113     123     47.0     164.9     221.1    1
# 27  ...     105    113    106      95     74.0      85.7     132.8    0
# 28  ...     104     90    102     112     85.0      55.9      37.0    0
# 29  ...     113    117    113      89    171.0     179.0     211.3    0
# 30  ...     102    115    109     146    121.0      34.0     174.0    0
# 31  ...     103    112    111     203    145.0      41.7     227.5    0
# 32  ...     104     99    108     182     30.0      65.6     140.9    0
# 33  ...      99    106    102     116     42.0     -17.9      42.5    1
# 34  ...     106    101    109     155    106.0      97.7     182.8    1
# 35  ...     113    118    115     117    150.0     184.5     255.3    0
# 36  ...     113    120    121     193     96.0     178.2     394.9    0
# 37  ...     102    110    111     212    156.0      35.0     234.2    0
# 38  ...     109     93    112     248     49.0     125.1     211.1    0
# 39  ...     104    107    105     113     62.0      50.6      80.9    0
#
#     MVP Share     Year
# 0       0.928  1990-91
# 1       0.888  2011-12
# 2       0.173  2018-19
# 3       0.495  2009-10
# 4       0.720  2014-15
# 5       0.345  2020-21
# 6       0.018  2019-20
# 7       0.938  1991-92
# 8       0.980  2009-10
# 9       0.922  2014-15
# 10      0.735  2011-12
# 11      0.768  2018-19
# 12      0.932  2018-19
# 13      0.875  2021-22
# 14      0.577  1992-93
# 15      0.731  2017-18
# 16      0.051  2016-17
# 17      0.112  2015-16
# 18      0.068  2013-14
# 19      0.007  2016-17
# 20      0.986  1995-96
# 21      0.998  2012-13
# 22      1.000  2015-16
# 23      0.986  2013-14
# 24      0.955  2017-18
# 25      0.952  2019-20
# 26      0.961  2020-21
# 27      0.832  1996-97
# 28      0.746  2019-20
# 29      0.053  2013-14
# 30      0.157  2010-11
# 31      0.363  2019-20
# 32      0.074  2017-18
# 33      0.934  1997-98
# 34      0.969  2008-09
# 35      0.449  2020-21
# 36      0.632  2012-13
# 37      0.746  2016-17
# 38      0.595  2021-22
# 39      0.210  2018-19
#
# [40 rows x 119 columns]

# %%
histo_test.to_csv('HistoTest.csv')
