# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('MVP_Candidates.csv')

# %%
jordan = df[(df['Player'] == 'Michael Jordan')].reset_index(drop=True)
jordan = jordan.sort_values('MVP Share', ascending=False)
jordan = jordan.iloc[0:6].reset_index(drop=True)
jordan
# Out:
#            Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Michael Jordan  SG       2   32  CHI  82  82     1  0.878049  3090  ...
# 1  Michael Jordan  SG       2   28  CHI  80  80     1  0.817073  3102  ...
# 2  Michael Jordan  SG       2   34  CHI  82  82     1  0.756098  3181  ...
# 3  Michael Jordan  SG       2   27  CHI  82  82     2  0.743902  3034  ...
# 4  Michael Jordan  SG       2   33  CHI  82  82     1  0.841463  3106  ...
# 5  Michael Jordan  SG       2   29  CHI  78  78     3  0.695122  3067  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     105    113    107     108     70.0      97.7     172.3    1      0.986
# 1     108    110    109     106     63.0     142.6     196.0    1      0.938
# 2      99    106    102     116     42.0     -17.9      42.5    1      0.934
# 3     112    111    113     114     62.0     218.6     301.1    1      0.928
# ...

# %%
hakeem = df[(df['Player'] == 'Hakeem Olajuwon')].reset_index(drop=True)
hakeem = hakeem.sort_values('MVP Share', ascending=False)
hakeem = hakeem.iloc[0:6].reset_index(drop=True)
hakeem
# Out:
#             Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Hakeem Olajuwon   C       5   31  HOU  80  80     2  0.707317  3277  ...
# 1  Hakeem Olajuwon   C       5   30  HOU  82  82     4  0.670732  3242  ...
# 2  Hakeem Olajuwon   C       5   33  HOU  72  72     8  0.585366  2797  ...
# 3  Hakeem Olajuwon   C       5   32  HOU  72  72    11  0.573171  2853  ...
# 4  Hakeem Olajuwon   C       5   34  HOU  78  78     4  0.695122  2852  ...
# 5  Hakeem Olajuwon   C       5   28  HOU  56  50     8  0.634146  2062  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     109     97    107     101     10.0     152.0     144.1    1      0.880
# 1     108    103    108     110      5.0     122.6     151.6    0      0.660
# 2     103     98    103     111      5.0      48.8      55.2    0      0.211
# 3     104    103    104     105      6.0      54.5      71.1    0      0.140
# ...

# %%
chuck = df[(df['Player'] == 'Charles Barkley')].reset_index(drop=True)
chuck = chuck.sort_values('MVP Share', ascending=False)
chuck = chuck.iloc[0:6].reset_index(drop=True)
chuck
# Out:
#             Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Charles Barkley  PF       4   29  PHO  76  76     1  0.756098  2859  ...
# 1  Charles Barkley  SF       3   27  PHI  67  67    12  0.536585  2498  ...
# 2  Charles Barkley  PF       4   31  PHO  68  66     3  0.719512  2382  ...
# 3  Charles Barkley  SF       3   28  PHI  75  75    19  0.426829  2881  ...
# 4  Charles Barkley  PF       4   32  PHO  71  71    15  0.500000  2632  ...
# 5  Charles Barkley  PF       4   30  PHO  65  65     5  0.682927  2298  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     111    101    111     131    153.0     148.4     193.4    1      0.852
# 1     121     94    119     176    162.0     236.6     292.3    0      0.231
# 2     104    101    105     134    102.0      41.4      80.0    0      0.091
# 3     116     92    115     190    139.0     179.5     228.0    0      0.019
# ...

# %%
david = df[(df['Player'] == 'David Robinson')].reset_index(drop=True)
david = david.sort_values('MVP Share', ascending=False)
david = david.iloc[0:6].reset_index(drop=True)
david
# Out:
#            Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  David Robinson   C       5   29  SAS  81  81     1  0.756098  3074  ...
# 1  David Robinson   C       5   28  SAS  80  80     7  0.670732  3241  ...
# 2  David Robinson   C       5   30  SAS  82  82     4  0.719512  3019  ...
# 3  David Robinson   C       5   25  SAS  82  81     6  0.670732  3095  ...
# 4  David Robinson   C       5   26  SAS  68  68    10  0.573171  2564  ...
# 5  David Robinson   C       5   27  SAS  82  82     8  0.597561  3211  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     106    105    111     171      7.0      95.5     218.9    1      0.858
# 1     105    102    109     177     15.0      81.0     203.2    0      0.723
# 2     104    103    109     181      3.0      50.5     164.8    0      0.508
# 3     113    100    115     178      6.0     177.7     275.7    0      0.496
# ...

# %%
karl = df[(df['Player'] == 'Karl Malone')].reset_index(drop=True)
karl = karl.sort_values('MVP Share', ascending=False)
karl = karl.iloc[0:6].reset_index(drop=True)
karl
# Out:
#         Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Karl Malone  PF       4   33  UTA  82  82     2  0.780488  2998  ...
# 1  Karl Malone  PF       4   34  UTA  81  81     2  0.756098  3030  ...
# 2  Karl Malone  PF       4   35  UTA  49  49     2  0.740000  1832  ...
# 3  Karl Malone  PF       4   31  UTA  82  82     2  0.731707  3126  ...
# 4  Karl Malone  PF       4   28  UTA  81  81     5  0.670732  3054  ...
# 5  Karl Malone  PF       4   36  UTA  82  82     4  0.670732  2947  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     112    102    112     137      4.0     179.1     240.9    1      0.857
# 1     111    103    114     170      3.0     154.6     268.5    0      0.726
# 2     106    108    113     183      1.0      44.0     132.8    1      0.701
# 3     108    101    109     135     14.0     123.5     174.3    0      0.507
# 4     108    103    113     187     13.0     122.7     256.3    0      0.273
# ...

# %%
shaq = df[(df['Player'] == "Shaquille O'Neal")].reset_index(drop=True)
shaq = shaq.sort_values('MVP Share', ascending=False)
shaq = shaq.iloc[0:6].reset_index(drop=True)
shaq
# Out:
#              Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Shaquille O'Neal   C       5   27  LAL  79  79     1  0.817073  3163  ...
# 1  Shaquille O'Neal   C       5   32  MIA  73  73     2  0.719512  2492  ...
# 2  Shaquille O'Neal   C       5   22  ORL  79  79     4  0.695122  2923  ...
# 3  Shaquille O'Neal   C       5   29  LAL  67  66     2  0.707317  2422  ...
# 4  Shaquille O'Neal   C       5   28  LAL  74  74     2  0.682927  2924  ...
# 5  Shaquille O'Neal   C       5   21  ORL  81  81    10  0.609756  3224  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     120     70    111     161      NaN     319.7     223.9    1      0.998
# 1     125     61    110     215      NaN     259.7     153.2    0      0.813
# 2     117     72    108     161      2.0     266.5     176.4    0      0.576
# 3     121     74    113     199      NaN     251.2     214.8    0      0.552
# ...

# %%
ai = df[(df['Player'] == "Allen Iverson")].reset_index(drop=True)
ai = ai.sort_values('MVP Share', ascending=False)
ai = ai.iloc[0:6].reset_index(drop=True)
ai
# Out:
#           Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Allen Iverson  SG       2   25  PHI  71  71     3  0.682927  2979  ...
# 1  Allen Iverson  SG       2   23  PHI  48  48    12  0.560000  1990  ...
# 2  Allen Iverson  PG       1   29  PHI  75  75    16  0.524390  3174  ...
# 3  Allen Iverson  SG       2   24  PHI  70  70    11  0.597561  2853  ...
# 4  Allen Iverson  SG       2   27  PHI  82  82    10  0.585366  3485  ...
# 5  Allen Iverson  SG       2   26  PHI  60  59    14  0.524390  2622  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0      95    109    100     129     99.0     -92.5       1.6    1      0.904
# 1      94    103     99     136    112.0     -55.2      -9.4    0      0.270
# 2      94    110    100     133     95.0    -107.8      10.9    0      0.189
# 3      93     95     95     116     90.0    -110.3    -108.4    0      0.109
# ...

# %%
giannis = df[(df['Player'] == 'Giannis Antetokounmpo')].reset_index(drop=True)
giannis
# Out:
#                   Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  \
# 0  Giannis Antetokounmpo  PF       4   27  MIL  67  67     7  0.621951  2204
# 1  Giannis Antetokounmpo  PF       4   26  MIL  61  61     7  0.638889  2013
# 2  Giannis Antetokounmpo  PF       4   25  MIL  63  63     1  0.767123  1917
# 3  Giannis Antetokounmpo  PF       4   24  MIL  72  72     1  0.731707  2358
# 4  Giannis Antetokounmpo  PF       4   23  MIL  75  75    16  0.536585  2756
# 5  Giannis Antetokounmpo  SF       3   22  MIL  80  80    14  0.512195  2845
#
#    ...  6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  \
# 0  ...     109     93    112     248     49.0     125.1     211.1    0
# 1  ...     111     88    111     214     51.0     135.6     166.7    0
# 2  ...     111     82    109     195     62.0     149.6     146.2    1
# 3  ...     114     95    115     213     45.0     186.6     260.5    1
# 4  ...     104     99    108     182     30.0      65.6     140.9    0
# ...

# %%
jokic = df[(df['Player'] == 'Nikola Jokić')].reset_index(drop=True)
jokic
# Out:
#          Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Nikola Jokić   C       5   26  DEN  74  74    10  0.585366  2476  ...
# 1  Nikola Jokić   C       5   25  DEN  72  72     5  0.652778  2488  ...
# 2  Nikola Jokić   C       5   24  DEN  73  73     6  0.630137  2336  ...
# 3  Nikola Jokić   C       5   23  DEN  80  80     4  0.658537  2504  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     117    105    117     144     55.0     230.9     286.9    1      0.875
# 1     112    112    113     123     47.0     164.9     221.1    1      0.961
# 2     107    106    107     108     62.0      77.3      96.8    0      0.018
# 3     104    107    105     113     62.0      50.6      80.9    0      0.210
#
#       Year
# 0  2021-22
# 1  2020-21
# 2  2019-20
# 3  2018-19
#
# [4 rows x 119 columns]

# %%
harden = df[(df['Player'] == 'James Harden')].reset_index(drop=True)
harden
# Out:
#          Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  James Harden  PG       1   31  TOT  44  43     0  0.000000  1609  ...
# 1  James Harden  SG       2   30  HOU  68  68     8  0.611111  2483  ...
# 2  James Harden  PG       1   29  HOU  78  78     5  0.646341  2867  ...
# 3  James Harden  SG       2   28  HOU  72  72     1  0.792683  2551  ...
# 4  James Harden  PG       1   27  HOU  81  81     3  0.670732  2947  ...
# 5  James Harden  SG       2   26  HOU  82  82    17  0.500000  3125  ...
# 6  James Harden  SG       2   25  HOU  81  81     3  0.682927  2981  ...
# 7  James Harden  SG       2   24  HOU  73  73     5  0.658537  2777  ...
# 8  James Harden  SG       2   23  HOU  78  78    12  0.548780  2985  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     102    111    108     178    116.0      15.3      81.1    0      0.001
# 1     103    112    111     203    145.0      41.7     227.5    0      0.363
# ...

# %%
embiid = df[(df['Player'] == 'Joel Embiid')].reset_index(drop=True)
embiid
# Out:
#         Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Joel Embiid   C       5   27  PHI  68  68     8  0.621951  2297  ...
# 1  Joel Embiid   C       5   26  PHI  51  51     3  0.680556  1585  ...
# 2  Joel Embiid   C       5   24  PHI  64  64     7  0.621951  2154  ...
# 3  Joel Embiid   C       5   23  PHI  63  63     5  0.634146  1912  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     100    105    109     243     47.0       6.5     169.0    0      0.706
# 1     101    111    111     247     44.0      12.8     147.2    0      0.580
# 2      99    105    106     209     61.0     -18.0      99.4    0      0.049
# 3      99    100    103     176     60.0     -14.7      41.9    0      0.004
#
#       Year
# 0  2021-22
# 1  2020-21
# 2  2018-19
# 3  2017-18
#
# [4 rows x 119 columns]

# %%
kd = df[(df['Player'] == 'Kevin Durant')].reset_index(drop=True)
kd
# Out:
#          Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Kevin Durant  PF       4   33  BRK  55  55    14  0.536585  2047  ...
# 1  Kevin Durant  SF       3   30  GSW  78  78     3  0.695122  2702  ...
# 2  Kevin Durant  SF       3   29  GSW  68  68     3  0.707317  2325  ...
# 3  Kevin Durant  PF       4   28  GSW  62  62     1  0.817073  2070  ...
# 4  Kevin Durant  SF       3   27  OKC  72  72     5  0.670732  2578  ...
# 5  Kevin Durant  SF       3   25  OKC  81  81     2  0.719512  3122  ...
# 6  Kevin Durant  SF       3   24  OKC  81  81     2  0.731707  3119  ...
# 7  Kevin Durant  SF       3   23  OKC  66  66     3  0.712121  2546  ...
# 8  Kevin Durant  SF       3   22  OKC  78  78     7  0.670732  3038  ...
# 9  Kevin Durant  SF       3   21  OKC  82  82    10  0.609756  3239  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     107    117    112     148     67.0      85.3     177.1    0      0.001
# ...

# %%
steph = df[(df['Player'] == 'Stephen Curry')].reset_index(drop=True)
steph
# Out:
#           Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0  Stephen Curry  PG       1   33  GSW  64  64     3  0.646341  2211  ...
# 1  Stephen Curry  PG       1   32  GSW  63  63    14  0.541667  2152  ...
# 2  Stephen Curry  PG       1   30  GSW  69  69     3  0.695122  2331  ...
# 3  Stephen Curry  PG       1   29  GSW  51  51     3  0.707317  1631  ...
# 4  Stephen Curry  PG       1   28  GSW  79  79     1  0.817073  2638  ...
# 5  Stephen Curry  PG       1   27  GSW  79  79     1  0.890244  2700  ...
# 6  Stephen Curry  PG       1   26  GSW  80  80     1  0.817073  2613  ...
# 7  Stephen Curry  PG       1   25  GSW  78  78     8  0.621951  2846  ...
# 8  Stephen Curry  PG       1   24  GSW  78  78    10  0.573171  2983  ...
#
#    6.eFG+  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Share  \
# 0     104    119    106      98    153.0      53.4      96.0    0      0.004
# ...

# %%
lebron = df[(df['Player'] == 'LeBron James')].reset_index(drop=True)
lebron
# Out:
#           Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  ...  \
# 0   LeBron James   C       5   37  LAL  56  56    23  0.402439  2084  ...
# 1   LeBron James  PG       1   36  LAL  45  45     9  0.583333  1504  ...
# 2   LeBron James  PG       1   35  LAL  67  67     3  0.732394  2316  ...
# 3   LeBron James  SF       3   34  LAL  55  55    20  0.451220  1937  ...
# 4   LeBron James  PF       4   33  CLE  82  82     6  0.609756  3026  ...
# 5   LeBron James  SF       3   32  CLE  74  74     5  0.621951  2794  ...
# 6   LeBron James  SF       3   31  CLE  76  76     3  0.695122  2709  ...
# 7   LeBron James  SF       3   30  CLE  69  69     7  0.646341  2493  ...
# 8   LeBron James  PF       4   29  MIA  77  77     6  0.658537  2902  ...
# 9   LeBron James  PF       4   28  MIA  76  76     1  0.804878  2877  ...
# 10  LeBron James  SF       3   27  MIA  62  62     4  0.696970  2326  ...
# 11  LeBron James  SF       3   26  MIA  79  79     3  0.707317  3063  ...
# ...

# %%
dataframe = [jordan, hakeem, chuck, david, karl, shaq, ai]
current = [lebron, steph, kd, giannis, harden, jokic, embiid]

# %%
# Series to DataFrame Row
def stdfr(ser): 
    dfrow = pd.DataFrame(ser).transpose()
    return dfrow

# %%
# 2021-22
d2122 = pd.concat([df.iloc[[0]] for df in dataframe]).reset_index(drop=True)

# 2020-21
d2021 = pd.concat([df.iloc[[1]] for df in dataframe]).reset_index(drop=True)

# 2019-20
d1920 = pd.concat([df.iloc[[2]] for df in dataframe]).reset_index(drop=True)

# 2018-19
d1819 = pd.concat([df.iloc[[3]] for df in dataframe]).reset_index(drop=True)

# 2017-18
d1718 = pd.concat([df.iloc[[4]] for df in dataframe]).reset_index(drop=True)

# 2015-16
d1516 = pd.concat([df.iloc[[4]] for df in dataframe]).reset_index(drop=True)

d = {'2015-16':d1516, '2017-18':d1718, '2018-19':d1819, '2019-20':d1920, '2020-21':d2021, '2021-22':d2122}

# %%
# 2021-22
d2122 = pd.concat([d2122, stdfr(giannis.iloc[0]), stdfr(steph.iloc[0]), stdfr(jokic.iloc[0]), stdfr(embiid.iloc[0]), stdfr(kd.iloc[0]), stdfr(lebron.iloc[0])]).reset_index(drop=True)

# 2020-21
d2021 = pd.concat([d2021, stdfr(giannis.iloc[1]), stdfr(steph.iloc[1]), stdfr(jokic.iloc[1]), stdfr(embiid.iloc[1]), stdfr(harden.iloc[0]), stdfr(lebron.iloc[1])]).reset_index(drop=True)

# 2019-20
d1920 = pd.concat([d1920, stdfr(giannis.iloc[2]), stdfr(jokic.iloc[2]), stdfr(harden.iloc[1]), stdfr(lebron.iloc[2])]).reset_index(drop=True)

# 2018-19
d1819 = pd.concat([d1819, stdfr(giannis.iloc[3]), stdfr(steph.iloc[2]), stdfr(jokic.iloc[3]), stdfr(embiid.iloc[2]), stdfr(harden.iloc[2]), stdfr(kd.iloc[1]), stdfr(lebron.iloc[3])]).reset_index(drop=True)

# 2017-18
d1718 = pd.concat([d1718, stdfr(giannis.iloc[4]), stdfr(steph.iloc[3]), stdfr(harden.iloc[3]), stdfr(embiid.iloc[3]), stdfr(kd.iloc[2]), stdfr(lebron.iloc[4])]).reset_index(drop=True)

# 2015-16
d1516 = pd.concat([d1516, stdfr(harden.iloc[5]), stdfr(steph.iloc[5]), stdfr(kd.iloc[4]), stdfr(lebron.iloc[6])]).reset_index(drop=True)

# %%
seasons = ['2015-16', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22']

# %%
leagueavs = pd.read_csv('LeagueAveragesByYear.csv')

# %%
for season in seasons:
    yearavs = leagueavs[(leagueavs['Season'] == season)].reset_index(drop=True)
    possper48 = yearavs['Pace']
    dseason = d[season]
    mult_factor = possper48 / (48 * 100)
    for i in dseason.index:
        mf = dseason['2.MP'][i] * mult_factor
        dseason['2.FG'][i] = mf * dseason['4.FG'][i]
        dseason['2.FGA'][i] = mf * dseason['4.FGA'][i]
        dseason['2.3P'][i] = mf * dseason['4.3P'][i]
        dseason['2.3PA'][i] = mf * dseason['4.3PA'][i]
        dseason['2.2P'][i] = mf * dseason['4.2P'][i]
        dseason['2.2PA'][i] = mf * dseason['4.2PA'][i]
        dseason['2.FT'][i] = mf * dseason['4.FT'][i]
        dseason['2.FTA'][i] = mf * dseason['4.FTA'][i]
        dseason['2.ORB'][i] = mf * dseason['4.ORB'][i]
        dseason['2.DRB'][i] = mf * dseason['4.DRB'][i]
        dseason['2.TRB'][i] = mf * dseason['4.TRB'][i]
        dseason['2.AST'][i] = mf * dseason['4.AST'][i]
        dseason['2.STL'][i] = mf * dseason['4.STL'][i]
        dseason['2.BLK'][i] = mf * dseason['4.BLK'][i]
        dseason['2.TOV'][i] = mf * dseason['4.TOV'][i]
        dseason['2.PF'][i] = mf * dseason['4.PF'][i]
        dseason['2.PTS'][i] = mf * dseason['4.PTS'][i]

        dseason['1.FG'][i] = dseason['G'][i] * dseason['2.FG'][i]
        dseason['1.FGA'][i] = dseason['G'][i] * dseason['2.FGA'][i]
        dseason['1.3P'][i] = dseason['G'][i] * dseason['2.3P'][i]
        dseason['1.3PA'][i] = dseason['G'][i] * dseason['2.3PA'][i]
        dseason['1.2P'][i] = dseason['G'][i] * dseason['2.2P'][i]
        dseason['1.2PA'][i] = dseason['G'][i] * dseason['2.2PA'][i]
        dseason['1.FT'][i] = dseason['G'][i] * dseason['2.FT'][i]
        dseason['1.FTA'][i] = dseason['G'][i] * dseason['2.FTA'][i]
        dseason['1.ORB'][i] = dseason['G'][i] * dseason['2.ORB'][i]
        dseason['1.DRB'][i] = dseason['G'][i] * dseason['2.DRB'][i]
        dseason['1.TRB'][i] = dseason['G'][i] * dseason['2.TRB'][i]
        dseason['1.AST'][i] = dseason['G'][i] * dseason['2.AST'][i]
        dseason['1.STL'][i] = dseason['G'][i] * dseason['2.STL'][i]
        dseason['1.BLK'][i] = dseason['G'][i] * dseason['2.BLK'][i]
        dseason['1.TOV'][i] = dseason['G'][i] * dseason['2.TOV'][i]
        dseason['1.PF'][i] = dseason['G'][i] * dseason['2.PF'][i]
        dseason['1.PTS'][i] = dseason['G'][i] * dseason['2.PTS'][i]
# Out:
# C:\Users\ishan\AppData\Local\Temp\ipykernel_14832\3588231187.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.FG'][i] = mf * dseason['4.FG'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_14832\3588231187.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dseason['2.FGA'][i] = mf * dseason['4.FGA'][i]
# C:\Users\ishan\AppData\Local\Temp\ipykernel_14832\3588231187.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
d = {'2015-16':d1516, '2017-18':d1718, '2018-19':d1819, '2019-20':d1920, '2020-21':d2021, '2021-22':d2122}

# %%
histo_test3 = pd.DataFrame()
for i in d.values():
    print(len(i))
    histo_test3 = pd.concat([histo_test3, i], ignore_index=True)
# Out:
# 11
# 13
# 14
# 11
# 13
# 13

# %%
print(histo_test3.to_string())
# Out:
#                    Player Pos Pos_No Age   Tm   G  GS Seed     Win %  1.MP 1.FG 1.FGA 1.3P 1.3PA 1.2P 1.2PA 1.FT 1.FTA 1.ORB 1.DRB 1.TRB 1.AST 1.STL 1.BLK 1.TOV 1.PF 1.PTS  2.MP  2.FG 2.FGA  2.FG% 2.3P 2.3PA  2.3P%  2.2P 2.2PA  2.2P% 2.eFG%  2.FT 2.FTA  2.FT% 2.ORB 2.DRB 2.TRB 2.AST 2.STL 2.BLK 2.TOV 2.PF 2.PTS  3.FG 3.FGA 3.3P 3.3PA  3.2P 3.2PA  3.FT 3.FTA 3.ORB 3.DRB 3.TRB 3.AST 3.STL 3.BLK 3.TOV 3.PF 3.PTS  4.FG 4.FGA 4.3P 4.3PA  4.2P 4.2PA  4.FT 4.FTA 4.ORB 4.DRB 4.TRB 4.AST 4.STL 4.BLK 4.TOV 4.PF 4.PTS 5.ORtg 5.DRtg 5.PER  5.TS% 5.3PAr  5.FTr 5.ORB% 5.DRB% 5.TRB% 5.AST% 5.STL% 5.BLK% 5.TOV% 5.USG% 5.OWS 5.DWS  5.WS 5.WS/48 5.OBPM 5.DBPM 5.BPM 5.VORP 6.FG+ 6.2P+  6.3P+ 6.eFG+ 6.FT+ 6.TS+ 6.FTr+ 6.3PAr+ 6.FG Add 6.TS Add MVP MVP Share     Year
# ...

# %%
histo_test3.to_csv('HistoTest3.csv')
