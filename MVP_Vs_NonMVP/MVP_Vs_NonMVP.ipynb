# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('MVP_Candidates_Complete.csv')

# %%
sns.relplot(data=df, x='5.PER', y='5.WS/48', hue='MVP')

# %%
sns.relplot(data=df, x='5.PER', y='5.WS', hue='MVP')

# %%
sns.relplot(data=df, x='5.PER', y='5.BPM', hue='MVP')

# %%
sns.relplot(data=df, x='5.BPM', y='5.WS/48', hue='MVP')

# %%
sns.relplot(data=df, x='5.BPM', y='5.WS', hue='MVP')

# %%
sns.relplot(data=df, x='5.PER', y='Win %', hue='MVP')

# %%
sns.relplot(data=df, x='5.WS', y='Win %', hue='MVP')

# %%
sns.relplot(data=df, x='5.WS/48', y='Win %', hue='MVP')

# %%
sns.relplot(data=df, x='5.BPM', y='Win %', hue='MVP')
