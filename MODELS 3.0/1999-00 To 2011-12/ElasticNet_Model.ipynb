# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import shap
import os
import pickle

import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_clustering.py:35: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _pt_shuffle_rec(i, indexes, index_mask, partition_tree, M, pos):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_clustering.py:54: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def delta_minimization_order(all_masks, max_swap_size=100, num_passes=2):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_clustering.py:63: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window(order, start, length):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_clustering.py:69: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window_score_gain(masks, order, start, length):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_clustering.py:77: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _mask_delta_score(m1, m2):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\links.py:5: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def identity(x):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\links.py:10: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _identity_inverse(x):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\links.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def logit(x):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\links.py:20: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _logit_inverse(x):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_masked_model.py:363: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_single_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_masked_model.py:385: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_multi_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_masked_model.py:428: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _init_masks(cluster_matrix, M, indices_row_pos, indptr):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\utils\_masked_model.py:439: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _rec_fill_masks(cluster_matrix, indices_row_pos, indptr, indices, M, ind):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\maskers\_tabular.py:186: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _single_delta_mask(dind, masked_inputs, last_mask, data, x, noop_code):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\maskers\_tabular.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _delta_masking(masks, x, curr_delta_inds, varying_rows_out,
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\maskers\_image.py:175: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _jit_build_partition_tree(xmin, xmax, ymin, ymax, zmin, zmax, total_ywidth, total_zwidth, M, clustering, q):
# c:\Users\ishan\AppData\Local\Programs\Python\Python310\lib\site-packages\shap\explainers\_partition.py:676: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def lower_credit(i, value, M, values, clustering):
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.

# %%
df = pd.read_csv('MVP_Candidates.csv')
df.fillna(0)
# Out:
#      Unnamed: 0.1  Unnamed: 0                 Player Pos  Pos_No  Age   Tm  \
# 0               0           0           Nikola Jokić   C       5   26  DEN
# 1               1           1            Joel Embiid   C       5   27  PHI
# 2               2           2  Giannis Antetokounmpo  PF       4   27  MIL
# 3               3           3           Devin Booker  SG       2   25  PHO
# 4               4           4            Luka Dončić  PG       1   22  DAL
# ..            ...         ...                    ...  ..     ...  ...  ...
# 480           481         481           Bernard King  SF       3   34  WSB
# 481           482         482            Kenny Smith  PG       1   25  HOU
# 482           483         483        Hakeem Olajuwon   C       5   28  HOU
# 483           484         484           Tim Hardaway  PG       1   24  GSW
# 484           485         485           Kevin McHale  PF       4   33  BOS
#
#       G  GS  Seed  ...  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  \
# 0    74  74    10  ...    105    117     144       55     230.9     286.9
# 1    68  68     8  ...    105    109     243       47       6.5     169.0
# 2    67  67     7  ...     93    112     248       49     125.1     211.1
# 3    68  68     1  ...    112    102     103       84      -4.1      32.6
# 4    65  65     5  ...     96    101     140      102      -8.9      15.3
# ..   ..  ..   ...  ...    ...    ...     ...      ...       ...       ...
# 480  64  64    20  ...    103     99     100       30     -38.6     -26.0
# 481  78  78     8  ...    110    112     106      164     115.5     148.1
# 482  56  50     8  ...    101    103      90        5      39.4      31.8
# 483  82  82    11  ...    105    102      77      198      63.4      44.2
# 484  68  10     4  ...    108    113      94       50     134.2     146.9
#
#      MVP  MVP Rank  MVP Share     Year
# 0      1         1      0.875  2021-22
# 1      0         2      0.706  2021-22
# 2      0         3      0.595  2021-22
# 3      0         4      0.216  2021-22
# 4      0         5      0.146  2021-22
# ..   ...       ...        ...      ...
# 480    0        16      0.007  1990-91
# 481    0        17      0.005  1990-91
# 482    0        18      0.004  1990-91
# 483    0        19      0.001  1990-91
# 484    0        19      0.001  1990-91
#
# [485 rows x 122 columns]

# %%
'''
1990-91 to 1998-99
1999-00 to 2011-12
2012-13 to 2021-22
'''
e1 = ('2021-22', '2020-21', '2019-20', '2018-19', '2017-18', '2016-17', '2015-16', '2014-15', '2013-14', '2012-13')
e2 = ('2011-12', '2010-09', '2008-09', '2007-08', '2006-07', '2005-06', '2004-05', '2003-04', '2002-03', '2001-02', '2000-01', '1999-00')
e3 = ('1998-99', '1997-98', '1996-97', '1995-96', '1994-95', '1993-94', '1992-93', '1991-92', '1990-91')


df1 = df[(df['Year'] == '2011-12') | (df['Year'] == '2010-11') | (df['Year'] == '2009-10') | (df['Year'] == '2008-09') | (df['Year'] == '2007-08') | (df['Year'] == '2006-07') | (df['Year'] == '2005-06') | (df['Year'] == '2004-05') | (df['Year'] == '2003-04') | (df['Year'] == '2002-03') | (df['Year'] == '2001-02') | (df['Year'] == '2000-01') | (df['Year'] == '1999-00')].reset_index(drop=True)

# %%
df1
# Out:
#      Unnamed: 0.1  Unnamed: 0             Player Pos  Pos_No  Age   Tm   G  \
# 0             130         130       LeBron James  SF       3   27  MIA  62
# 1             131         131       Kevin Durant  SF       3   23  OKC  66
# 2             132         132         Chris Paul  PG       1   26  LAC  60
# 3             133         133        Kobe Bryant  SG       2   33  LAL  58
# 4             134         134        Tony Parker  PG       1   29  SAS  60
# ..            ...         ...                ...  ..     ...  ...  ...  ..
# 191           321         321        Kobe Bryant  SG       2   21  LAL  66
# 192           322         322  Darrell Armstrong  PG       1   31  ORL  82
# 193           323         323     Michael Finley  SF       3   26  DAL  82
# 194           324         324      Reggie Miller  SG       2   34  IND  81
# 195           325         325         Jalen Rose  SF       3   27  IND  80
#
#      GS  Seed  ...  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  \
# 0    62     4  ...    102    115     156       56     156.7     217.8    1
# 1    66     3  ...    114    116     140      117     155.0     250.3    0
# 2    60     9  ...    114    110     123      106      61.6     110.7    0
# 3    58     6  ...    112    100     122       95     -67.1      -1.6    0
# 4    60     2  ...    106    102     116       30       0.6      25.0    0
# ..   ..   ...  ...    ...    ...     ...      ...       ...       ...  ...
# 191  62     1  ...    109    104     111       73      22.7      62.6    0
# 192  82    17  ...    121    104      72      216      34.9      46.3    0
# 193  82    18  ...    109    100      63       90      30.4      -1.5    0
# 194  81     3  ...    122    115     127      232     101.5     194.7    0
# 195  80     3  ...    110    105      83       98      59.2      65.2    0
#
#      MVP Rank  MVP Share     Year
# 0           1      0.888  2011-12
# 1           2      0.735  2011-12
# 2           3      0.318  2011-12
# 3           4      0.291  2011-12
# 4           5      0.274  2011-12
# ..        ...        ...      ...
# 191        12      0.002  1999-00
# 192        13      0.001  1999-00
# 193        13      0.001  1999-00
# 194        13      0.001  1999-00
# 195        13      0.001  1999-00
#
# [196 rows x 122 columns]

# %%
df1.drop(df1.columns[[0, 1]], axis = 1, inplace=True)

# %%
#df1['6.3P+'][108] = 0
''' WHY WAS THIS NaN I HAVE NO CLUE - FILLNA SHOULD HAVE MADE IT ZERO '''
''' ANYWAY PROBLEM SOLVED '''
# Out:
# ' ANYWAY PROBLEM SOLVED '

# %%
df1.to_csv('LessModernEra.csv', index=False)

# %%
df1
# Out:
#                 Player Pos  Pos_No  Age   Tm   G  GS  Seed     Win %  1.MP  \
# 0         LeBron James  SF       3   27  MIA  62  62     4  0.696970  2326
# 1         Kevin Durant  SF       3   23  OKC  66  66     3  0.712121  2546
# 2           Chris Paul  PG       1   26  LAC  60  60     9  0.606061  2181
# 3          Kobe Bryant  SG       2   33  LAL  58  58     6  0.621212  2232
# 4          Tony Parker  PG       1   29  SAS  60  60     2  0.757576  1923
# ..                 ...  ..     ...  ...  ...  ..  ..   ...       ...   ...
# 191        Kobe Bryant  SG       2   21  LAL  66  62     1  0.817073  2524
# 192  Darrell Armstrong  PG       1   31  ORL  82  82    17  0.500000  2590
# 193     Michael Finley  SF       3   26  DAL  82  82    18  0.487805  3464
# 194      Reggie Miller  SG       2   34  IND  81  81     3  0.682927  2987
# 195         Jalen Rose  SF       3   27  IND  80  80     3  0.682927  2978
#
#      ...  6.FT+  6.TS+  6.FTr+  6.3PAr+  6.FG Add  6.TS Add  MVP  MVP Rank  \
# 0    ...    102    115     156       56     156.7     217.8    1         1
# 1    ...    114    116     140      117     155.0     250.3    0         2
# 2    ...    114    110     123      106      61.6     110.7    0         3
# 3    ...    112    100     122       95     -67.1      -1.6    0         4
# 4    ...    106    102     116       30       0.6      25.0    0         5
# ..   ...    ...    ...     ...      ...       ...       ...  ...       ...
# 191  ...    109    104     111       73      22.7      62.6    0        12
# 192  ...    121    104      72      216      34.9      46.3    0        13
# 193  ...    109    100      63       90      30.4      -1.5    0        13
# 194  ...    122    115     127      232     101.5     194.7    0        13
# 195  ...    110    105      83       98      59.2      65.2    0        13
#
#      MVP Share     Year
# 0        0.888  2011-12
# 1        0.735  2011-12
# 2        0.318  2011-12
# 3        0.291  2011-12
# 4        0.274  2011-12
# ..         ...      ...
# 191      0.002  1999-00
# 192      0.001  1999-00
# 193      0.001  1999-00
# 194      0.001  1999-00
# 195      0.001  1999-00
#
# [196 rows x 120 columns]

# %%
def calc_metrics(y_test, y_pred):
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    return rmse, r2

# %%
seasons = ['2011-12', '2010-11', '2009-10' ,'2008-09', '2007-08', '2006-07', '2005-06', '2004-05', '2003-04', '2002-03', '2001-02', '2000-01', '1999-00']

# %%
col_to_drop = []
for i in df1.columns:
    if i[0] == '3' or i[0] == '4':
        col_to_drop.append(i)

# %%
season_metrics = {season:[] for season in seasons}
all_results = pd.DataFrame(columns = ['Year', 'Player', 'MVP Share', 'MVP Rank', 'Predicted MVP Share'])

# %%
for season in seasons:
    
    testing_data = df1[(df1['Year'] == season)].copy()
    training_data = df1[(df1['Year'] != season)].copy()
    X_train = training_data.drop(['Player', 'Pos', 'Tm', 'MVP', 'MVP Rank', 'MVP Share', 'Year'] + col_to_drop, axis=1)
    Y_train = training_data['MVP Share']
    X_test = testing_data.drop(['Player', 'Pos', 'Tm', 'MVP', 'MVP Rank', 'MVP Share', 'Year'] + col_to_drop, axis=1)
    Y_test = testing_data['MVP Share']

    X_train.fillna(0)
    X_test.fillna(0)

    scaler = StandardScaler()
    scaled_X_train = scaler.fit_transform(X_train)
    scaled_X_test = scaler.transform(X_test)

    final_params = []

    param_grid = {'alpha':[0.01,0.1,1,5,10,50,100],
                    'l1_ratio':[0.01,0.1,0.5,0.7,0.95,0.99,1]}
    elastic_net_model = ElasticNet()
    grid = GridSearchCV(elastic_net_model, param_grid)
    grid.fit(scaled_X_train, Y_train)
    grid.best_params_
    model = ElasticNet(**grid.best_params_)
    final_params.append(grid.best_params_)

    model.fit(scaled_X_train, Y_train)

    Y_pred = model.predict(scaled_X_test)

    rmse, r2 = calc_metrics(Y_test, Y_pred)

    season_metrics[season] += [rmse, r2]

    initial_results = testing_data[['Year', 'Player', 'MVP Share', 'MVP Rank']]
    results = initial_results.copy()
    results['Predicted MVP Share'] = pd.Series(Y_pred).values
    results = results.sort_values('Predicted MVP Share', ascending=False).reset_index(drop=True)

    print(results)

    all_results = pd.concat([all_results, results])
# Out:
#        Year             Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2011-12       LeBron James      0.888         1             0.429543
# 1   2011-12       Kevin Durant      0.735         2             0.316232
# 2   2011-12  Russell Westbrook      0.003        12             0.130731
# 3   2011-12        Dwyane Wade      0.005        10             0.124597
# 4   2011-12       Derrick Rose      0.004        11             0.120356
# 5   2011-12         Chris Paul      0.318         3             0.104291
# 6   2011-12        Tony Parker      0.274         5             0.093927
# 7   2011-12        Kobe Bryant      0.291         4             0.088574
# 8   2011-12         Tim Duncan      0.002        14             0.054264
# 9   2011-12      Dwight Howard      0.011         7             0.025678
# 10  2011-12         Steve Nash      0.006         9            -0.050181
# 11  2011-12        Joe Johnson      0.001        15            -0.072849
# 12  2011-12        Rajon Rondo      0.010         8            -0.075217
# 13  2011-12         Kevin Love      0.048         6            -0.081167
# 14  2011-12      Dirk Nowitzki      0.003        12            -0.082106
#        Year             Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2010-11       LeBron James      0.431         3             0.430155
# 1   2010-11       Derrick Rose      0.977         1             0.337224
# 2   2010-11        Dwyane Wade      0.020         7             0.293966
# 3   2010-11      Dwight Howard      0.531         2             0.289992
# 4   2010-11        Kobe Bryant      0.354         4             0.211195
# 5   2010-11       Kevin Durant      0.157         5             0.201539
# 6   2010-11      Dirk Nowitzki      0.093         6             0.165973
# 7   2010-11         Chris Paul      0.002        13             0.148756
# 8   2010-11      Manu Ginóbili      0.017         8             0.128164
# 9   2010-11        Tony Parker      0.002        12             0.088659
# 10  2010-11        Rajon Rondo      0.004        10             0.045096
# 11  2010-11  Amar'e Stoudemire      0.007         9            -0.005448
# 12  2010-11      Blake Griffin      0.004        10            -0.019554
#        Year             Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2009-10       LeBron James      0.980         1             0.738568
# 1   2009-10         Steve Nash      0.040         8             0.381484
# 2   2009-10       Kevin Durant      0.495         2             0.335971
# 3   2009-10        Dwyane Wade      0.097         5             0.294366
# 4   2009-10      Dwight Howard      0.389         4             0.253047
# 5   2009-10        Kobe Bryant      0.487         3             0.214428
# 6   2009-10     Deron Williams      0.006         9             0.114125
# 7   2009-10      Dirk Nowitzki      0.045         7             0.094317
# 8   2009-10        Joe Johnson      0.001        12             0.058042
# 9   2009-10  Amar'e Stoudemire      0.004        10             0.018992
# 10  2009-10    Carmelo Anthony      0.053         6             0.008186
# 11  2009-10   Chauncey Billups      0.001        12            -0.005757
# 12  2009-10      Manu Ginóbili      0.002        11            -0.027845
# 13  2009-10         Chris Bosh      0.001        12            -0.062041
# 14  2009-10    Stephen Jackson      0.001        12            -0.142918
#        Year            Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2008-09      LeBron James      0.969         1             0.772242
# 1   2008-09       Dwyane Wade      0.562         3             0.367990
# 2   2008-09       Kobe Bryant      0.577         2             0.338516
# 3   2008-09     Dwight Howard      0.271         4             0.328777
# 4   2008-09        Chris Paul      0.159         5             0.322795
# 5   2008-09        Tim Duncan      0.002        11             0.268512
# 6   2008-09       Brandon Roy      0.006         9             0.216427
# 7   2008-09       Tony Parker      0.007         8             0.146802
# 8   2008-09     Dirk Nowitzki      0.002        10             0.115186
# 9   2008-09       Paul Pierce      0.017         7             0.080459
# 10  2008-09          Yao Ming      0.001        12            -0.063378
# 11  2008-09  Chauncey Billups      0.027         6            -0.104040
#        Year             Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2007-08       LeBron James      0.348         4             0.453927
# 1   2007-08         Steve Nash      0.014         9             0.391122
# 2   2007-08         Tim Duncan      0.020         7             0.321560
# 3   2007-08      Kevin Garnett      0.532         3             0.317465
# 4   2007-08         Chris Paul      0.710         2             0.308840
# 5   2007-08        Kobe Bryant      0.873         1             0.299817
# 6   2007-08      Dwight Howard      0.048         5             0.235095
# 7   2007-08        Paul Pierce      0.001        14             0.232325
# 8   2007-08      Manu Ginóbili      0.007        10             0.203320
# 9   2007-08      Dirk Nowitzki      0.004        11             0.182781
# 10  2007-08  Amar'e Stoudemire      0.021         6             0.161897
# 11  2007-08     Deron Williams      0.003        12             0.155831
# 12  2007-08      Tracy McGrady      0.015         8             0.139280
# 13  2007-08      Carlos Boozer      0.001        14             0.064954
# 14  2007-08    Carmelo Anthony      0.002        13            -0.007909
# 15  2007-08     Antawn Jamison      0.001        14            -0.084004
# 16  2007-08    Rasheed Wallace      0.001        14            -0.090033
#        Year             Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2006-07      Dirk Nowitzki      0.882         1             0.398665
# 1   2006-07       LeBron James      0.142         5             0.380610
# 2   2006-07         Tim Duncan      0.222         4             0.373899
# 3   2006-07         Steve Nash      0.785         2             0.325214
# 4   2006-07      Tracy McGrady      0.085         6             0.239025
# 5   2006-07        Dwyane Wade      0.002        12             0.238140
# 6   2006-07        Kobe Bryant      0.404         3             0.207796
# 7   2006-07      Carlos Boozer      0.005         9             0.183253
# 8   2006-07        Tony Parker      0.001        15             0.136329
# 9   2006-07  Amar'e Stoudemire      0.002        14             0.133397
# 10  2006-07         Chris Bosh      0.033         7             0.067021
# 11  2006-07   Chauncey Billups      0.003        11             0.059427
# 12  2006-07      Kevin Garnett      0.005         9             0.051413
# 13  2006-07    Carmelo Anthony      0.001        15             0.040420
# 14  2006-07     Gilbert Arenas      0.024         8             0.013366
# 15  2006-07        Baron Davis      0.001        15            -0.067447
# 16  2006-07   Shaquille O'Neal      0.002        12            -0.175666
#        Year            Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2005-06      LeBron James      0.550         2             0.465891
# 1   2005-06     Dirk Nowitzki      0.435         3             0.430917
# 2   2005-06       Dwyane Wade      0.070         6             0.364978
# 3   2005-06       Kobe Bryant      0.386         4             0.349181
# 4   2005-06       Elton Brand      0.040         7             0.275234
# 5   2005-06        Steve Nash      0.739         1             0.266509
# 6   2005-06  Chauncey Billups      0.344         5             0.251745
# 7   2005-06        Tim Duncan      0.026         8             0.241093
# 8   2005-06      Shawn Marion      0.001        10             0.215172
# 9   2005-06       Tony Parker      0.007         9             0.187960
# 10  2005-06     Allen Iverson      0.001        10             0.163035
#        Year             Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2004-05      Kevin Garnett      0.012        11             0.352998
# 1   2004-05       LeBron James      0.073         6             0.335109
# 2   2004-05      Dirk Nowitzki      0.275         3             0.329478
# 3   2004-05         Tim Duncan      0.258         4             0.304737
# 4   2004-05      Tracy McGrady      0.035         7             0.301012
# 5   2004-05   Shaquille O'Neal      0.813         2             0.255100
# 6   2004-05      Allen Iverson      0.189         5             0.245787
# 7   2004-05         Steve Nash      0.839         1             0.240084
# 8   2004-05       Shawn Marion      0.001        14             0.220496
# 9   2004-05        Dwyane Wade      0.034         8             0.216078
# 10  2004-05  Amar'e Stoudemire      0.032         9             0.197108
# 11  2004-05          Ray Allen      0.032         9             0.116663
# 12  2004-05     Gilbert Arenas      0.003        12             0.028286
# 13  2004-05       Vince Carter      0.002        13            -0.083992
# 14  2004-05       Marcus Camby      0.001        14            -0.186712
# 15  2004-05         P.J. Brown      0.001        14            -0.648103
#        Year            Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2003-04     Kevin Garnett      0.991         1             0.487880
# 1   2003-04        Tim Duncan      0.582         2             0.341209
# 2   2003-04  Shaquille O'Neal      0.145         6             0.209793
# 3   2003-04       Sam Cassell      0.003        10             0.185406
# 4   2003-04   Peja Stojaković      0.228         4             0.157889
# 5   2003-04       Kobe Bryant      0.172         5             0.150980
# 6   2003-04  Andrei Kirilenko      0.002        13             0.130034
# 7   2003-04   Jermaine O'Neal      0.425         3             0.082930
# 8   2003-04     Dirk Nowitzki      0.003        10             0.079504
# 9   2003-04        Jason Kidd      0.014         8             0.058702
# 10  2003-04          Yao Ming      0.001        14             0.054219
# 11  2003-04       Baron Davis      0.003        10             0.038214
# 12  2003-04       Ben Wallace      0.020         7             0.014196
# 13  2003-04      Michael Redd      0.001        14            -0.050626
# 14  2003-04      LeBron James      0.009         9            -0.078457
# 15  2003-04   Carmelo Anthony      0.001        14            -0.098569
#        Year            Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2002-03        Tim Duncan      0.808         1             0.410035
# 1   2002-03     Kevin Garnett      0.732         2             0.380474
# 2   2002-03     Tracy McGrady      0.359         4             0.361083
# 3   2002-03       Kobe Bryant      0.417         3             0.343845
# 4   2002-03     Dirk Nowitzki      0.036         7             0.325027
# 5   2002-03  Shaquille O'Neal      0.106         5             0.305961
# 6   2002-03        Jason Kidd      0.026         9             0.250402
# 7   2002-03        Steve Nash      0.001        11             0.189742
# 8   2002-03     Allen Iverson      0.070         6             0.162668
# 9   2002-03      Chris Webber      0.016        10             0.146522
# 10  2002-03       Paul Pierce      0.001        11             0.146001
# 11  2002-03    Jamal Mashburn      0.001        11             0.041823
# 12  2002-03       Ben Wallace      0.028         8            -0.002589
#        Year            Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2001-02        Tim Duncan      0.757         1             0.456275
# 1   2001-02  Shaquille O'Neal      0.552         3             0.388658
# 2   2001-02     Kevin Garnett      0.013        12             0.259367
# 3   2001-02       Kobe Bryant      0.078         5             0.232101
# 4   2001-02     Tracy McGrady      0.310         4             0.207557
# 5   2001-02     Dirk Nowitzki      0.025         8             0.205833
# 6   2001-02       Paul Pierce      0.017        11             0.204280
# 7   2001-02      Chris Webber      0.029         7             0.192239
# 8   2001-02       Gary Payton      0.043         6             0.181749
# 9   2001-02        Jason Kidd      0.712         2             0.121094
# 10  2001-02        Steve Nash      0.004        14             0.115940
# 11  2001-02   Peja Stojaković      0.001        16             0.115016
# 12  2001-02     Allen Iverson      0.023         9             0.106098
# 13  2001-02       Elton Brand      0.001        16             0.070104
# 14  2001-02       Ben Wallace      0.019        10             0.030866
# 15  2001-02  Jerry Stackhouse      0.002        15             0.001743
# 16  2001-02        Mike Bibby      0.001        16            -0.098461
# 17  2001-02    Michael Jordan      0.013        13            -0.101667
#        Year            Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   2000-01  Shaquille O'Neal      0.466         3             0.429061
# 1   2000-01        Tim Duncan      0.569         2             0.281551
# 2   2000-01       Karl Malone      0.017         7             0.277325
# 3   2000-01     Allen Iverson      0.904         1             0.248794
# 4   2000-01      Chris Webber      0.420         4             0.244075
# 5   2000-01     Kevin Garnett      0.122         5             0.214659
# 6   2000-01     Tracy McGrady      0.052         6             0.208847
# 7   2000-01      Vince Carter      0.006        11             0.208508
# 8   2000-01         Ray Allen      0.006        11             0.198775
# 9   2000-01       Kobe Bryant      0.009         9             0.196790
# 10  2000-01    David Robinson      0.006        10             0.157595
# 11  2000-01     John Stockton      0.001        15             0.157049
# 12  2000-01        Jason Kidd      0.015         8             0.130068
# 13  2000-01  Jerry Stackhouse      0.002        14             0.118435
# 14  2000-01       Paul Pierce      0.004        13             0.056832
# 15  2000-01    Michael Finley      0.001        15             0.046103
# 16  2000-01     Anthony Mason      0.001        15             0.025651
#        Year             Player  MVP Share  MVP Rank  Predicted MVP Share
# 0   1999-00   Shaquille O'Neal      0.998         1             0.553589
# 1   1999-00        Karl Malone      0.258         4             0.346182
# 2   1999-00         Tim Duncan      0.205         5             0.273847
# 3   1999-00      Kevin Garnett      0.337         2             0.266192
# 4   1999-00        Gary Payton      0.149         6             0.239853
# 5   1999-00    Alonzo Mourning      0.303         3             0.195918
# 6   1999-00        Kobe Bryant      0.002        12             0.184486
# 7   1999-00         Grant Hill      0.093         8             0.144192
# 8   1999-00       Chris Webber      0.079         9             0.142556
# 9   1999-00         Jason Kidd      0.021        11             0.106718
# 10  1999-00       Vince Carter      0.042        10             0.106334
# 11  1999-00      Allen Iverson      0.109         7             0.068256
# 12  1999-00  Darrell Armstrong      0.001        13             0.015519
# 13  1999-00      Reggie Miller      0.001        13             0.014638
# 14  1999-00     Michael Finley      0.001        13            -0.020669
# 15  1999-00         Jalen Rose      0.001        13            -0.022096

# %%
for i in season_metrics.keys():
    print(i)
    print("RMSE = ", season_metrics[i][0])
    print("R2 = ", season_metrics[i][1])
    print()
# Out:
# 2011-12
# RMSE =  0.1985828773097474
# R2 =  0.48200461319202725
#
# 2010-11
# RMSE =  0.21731943726956737
# R2 =  0.42190604705660295
#
# 2009-10
# RMSE =  0.15856773468892074
# R2 =  0.6744327510504718
#
# 2008-09
# RMSE =  0.16743218009241878
# R2 =  0.7007720637512199
#
# 2007-08
# RMSE =  0.24461845279410696
# R2 =  0.20281525627050745
#
# 2006-07
# RMSE =  0.21070913043946898
# R2 =  0.39054429662831713
#
# 2005-06
# RMSE =  0.220266129609685
# R2 =  0.23576650155801127
#
# 2004-05
# RMSE =  0.3076562367726977
# R2 =  -0.3399519034400549
#
# 2003-04
# RMSE =  0.18019567390180338
# R2 =  0.5605542605890195
#
# 2002-03
# RMSE =  0.20494930643596748
# R2 =  0.4485458331209424
#
# 2001-02
# RMSE =  0.20211241741237612
# R2 =  0.34124475073838323
#
# 2000-01
# RMSE =  0.2220482161578879
# R2 =  0.27422605444196446
#
# 1999-00
# RMSE =  0.13445703701745806
# R2 =  0.6918369276324603

# %%
all_test = all_results['MVP Share']
all_pred = all_results['Predicted MVP Share']
total_rmse, total_r2 = calc_metrics(all_test, all_pred)
print("RMSE = ", total_rmse)
print("R2 = ", total_r2)
# Out:
# RMSE =  0.21029033839451491
# R2 =  0.3954935096987502

# %%
print(all_results.to_string())
# Out:
#        Year             Player MVP Share MVP Rank Predicted MVP Share
# 0   2011-12       LeBron James     0.888        1            0.429543
# 1   2011-12       Kevin Durant     0.735        2            0.316232
# 2   2011-12  Russell Westbrook     0.003       12            0.130731
# 3   2011-12        Dwyane Wade     0.005       10            0.124597
# 4   2011-12       Derrick Rose     0.004       11            0.120356
# 5   2011-12         Chris Paul     0.318        3            0.104291
# 6   2011-12        Tony Parker     0.274        5            0.093927
# 7   2011-12        Kobe Bryant     0.291        4            0.088574
# 8   2011-12         Tim Duncan     0.002       14            0.054264
# 9   2011-12      Dwight Howard     0.011        7            0.025678
# 10  2011-12         Steve Nash     0.006        9           -0.050181
# 11  2011-12        Joe Johnson     0.001       15           -0.072849
# 12  2011-12        Rajon Rondo      0.01        8           -0.075217
# 13  2011-12         Kevin Love     0.048        6           -0.081167
# 14  2011-12      Dirk Nowitzki     0.003       12           -0.082106
# 0   2010-11       LeBron James     0.431        3            0.430155
# 1   2010-11       Derrick Rose     0.977        1            0.337224
# 2   2010-11        Dwyane Wade      0.02        7            0.293966
# 3   2010-11      Dwight Howard     0.531        2            0.289992
# 4   2010-11        Kobe Bryant     0.354        4            0.211195
# 5   2010-11       Kevin Durant     0.157        5            0.201539
# 6   2010-11      Dirk Nowitzki     0.093        6            0.165973
# 7   2010-11         Chris Paul     0.002       13            0.148756
# 8   2010-11      Manu Ginóbili     0.017        8            0.128164
# 9   2010-11        Tony Parker     0.002       12            0.088659
# 10  2010-11        Rajon Rondo     0.004       10            0.045096
# 11  2010-11  Amar'e Stoudemire     0.007        9           -0.005448
# 12  2010-11      Blake Griffin     0.004       10           -0.019554
# 0   2009-10       LeBron James      0.98        1            0.738568
# 1   2009-10         Steve Nash      0.04        8            0.381484
# 2   2009-10       Kevin Durant     0.495        2            0.335971
# 3   2009-10        Dwyane Wade     0.097        5            0.294366
# 4   2009-10      Dwight Howard     0.389        4            0.253047
# 5   2009-10        Kobe Bryant     0.487        3            0.214428
# 6   2009-10     Deron Williams     0.006        9            0.114125
# 7   2009-10      Dirk Nowitzki     0.045        7            0.094317
# 8   2009-10        Joe Johnson     0.001       12            0.058042
# 9   2009-10  Amar'e Stoudemire     0.004       10            0.018992
# 10  2009-10    Carmelo Anthony     0.053        6            0.008186
# 11  2009-10   Chauncey Billups     0.001       12           -0.005757
# 12  2009-10      Manu Ginóbili     0.002       11           -0.027845
# 13  2009-10         Chris Bosh     0.001       12           -0.062041
# 14  2009-10    Stephen Jackson     0.001       12           -0.142918
# 0   2008-09       LeBron James     0.969        1            0.772242
# 1   2008-09        Dwyane Wade     0.562        3             0.36799
# 2   2008-09        Kobe Bryant     0.577        2            0.338516
# 3   2008-09      Dwight Howard     0.271        4            0.328777
# 4   2008-09         Chris Paul     0.159        5            0.322795
# 5   2008-09         Tim Duncan     0.002       11            0.268512
# 6   2008-09        Brandon Roy     0.006        9            0.216427
# 7   2008-09        Tony Parker     0.007        8            0.146802
# 8   2008-09      Dirk Nowitzki     0.002       10            0.115186
# 9   2008-09        Paul Pierce     0.017        7            0.080459
# 10  2008-09           Yao Ming     0.001       12           -0.063378
# 11  2008-09   Chauncey Billups     0.027        6            -0.10404
# 0   2007-08       LeBron James     0.348        4            0.453927
# 1   2007-08         Steve Nash     0.014        9            0.391122
# 2   2007-08         Tim Duncan      0.02        7             0.32156
# 3   2007-08      Kevin Garnett     0.532        3            0.317465
# 4   2007-08         Chris Paul      0.71        2             0.30884
# 5   2007-08        Kobe Bryant     0.873        1            0.299817
# 6   2007-08      Dwight Howard     0.048        5            0.235095
# 7   2007-08        Paul Pierce     0.001       14            0.232325
# 8   2007-08      Manu Ginóbili     0.007       10             0.20332
# 9   2007-08      Dirk Nowitzki     0.004       11            0.182781
# 10  2007-08  Amar'e Stoudemire     0.021        6            0.161897
# 11  2007-08     Deron Williams     0.003       12            0.155831
# 12  2007-08      Tracy McGrady     0.015        8             0.13928
# 13  2007-08      Carlos Boozer     0.001       14            0.064954
# 14  2007-08    Carmelo Anthony     0.002       13           -0.007909
# 15  2007-08     Antawn Jamison     0.001       14           -0.084004
# 16  2007-08    Rasheed Wallace     0.001       14           -0.090033
# 0   2006-07      Dirk Nowitzki     0.882        1            0.398665
# 1   2006-07       LeBron James     0.142        5             0.38061
# 2   2006-07         Tim Duncan     0.222        4            0.373899
# 3   2006-07         Steve Nash     0.785        2            0.325214
# 4   2006-07      Tracy McGrady     0.085        6            0.239025
# 5   2006-07        Dwyane Wade     0.002       12             0.23814
# 6   2006-07        Kobe Bryant     0.404        3            0.207796
# 7   2006-07      Carlos Boozer     0.005        9            0.183253
# 8   2006-07        Tony Parker     0.001       15            0.136329
# 9   2006-07  Amar'e Stoudemire     0.002       14            0.133397
# 10  2006-07         Chris Bosh     0.033        7            0.067021
# 11  2006-07   Chauncey Billups     0.003       11            0.059427
# 12  2006-07      Kevin Garnett     0.005        9            0.051413
# 13  2006-07    Carmelo Anthony     0.001       15             0.04042
# 14  2006-07     Gilbert Arenas     0.024        8            0.013366
# 15  2006-07        Baron Davis     0.001       15           -0.067447
# 16  2006-07   Shaquille O'Neal     0.002       12           -0.175666
# 0   2005-06       LeBron James      0.55        2            0.465891
# 1   2005-06      Dirk Nowitzki     0.435        3            0.430917
# 2   2005-06        Dwyane Wade      0.07        6            0.364978
# 3   2005-06        Kobe Bryant     0.386        4            0.349181
# 4   2005-06        Elton Brand      0.04        7            0.275234
# 5   2005-06         Steve Nash     0.739        1            0.266509
# 6   2005-06   Chauncey Billups     0.344        5            0.251745
# 7   2005-06         Tim Duncan     0.026        8            0.241093
# 8   2005-06       Shawn Marion     0.001       10            0.215172
# 9   2005-06        Tony Parker     0.007        9             0.18796
# 10  2005-06      Allen Iverson     0.001       10            0.163035
# 0   2004-05      Kevin Garnett     0.012       11            0.352998
# 1   2004-05       LeBron James     0.073        6            0.335109
# 2   2004-05      Dirk Nowitzki     0.275        3            0.329478
# 3   2004-05         Tim Duncan     0.258        4            0.304737
# 4   2004-05      Tracy McGrady     0.035        7            0.301012
# 5   2004-05   Shaquille O'Neal     0.813        2              0.2551
# 6   2004-05      Allen Iverson     0.189        5            0.245787
# 7   2004-05         Steve Nash     0.839        1            0.240084
# 8   2004-05       Shawn Marion     0.001       14            0.220496
# 9   2004-05        Dwyane Wade     0.034        8            0.216078
# 10  2004-05  Amar'e Stoudemire     0.032        9            0.197108
# 11  2004-05          Ray Allen     0.032        9            0.116663
# 12  2004-05     Gilbert Arenas     0.003       12            0.028286
# 13  2004-05       Vince Carter     0.002       13           -0.083992
# 14  2004-05       Marcus Camby     0.001       14           -0.186712
# 15  2004-05         P.J. Brown     0.001       14           -0.648103
# 0   2003-04      Kevin Garnett     0.991        1             0.48788
# 1   2003-04         Tim Duncan     0.582        2            0.341209
# 2   2003-04   Shaquille O'Neal     0.145        6            0.209793
# 3   2003-04        Sam Cassell     0.003       10            0.185406
# 4   2003-04    Peja Stojaković     0.228        4            0.157889
# 5   2003-04        Kobe Bryant     0.172        5             0.15098
# 6   2003-04   Andrei Kirilenko     0.002       13            0.130034
# 7   2003-04    Jermaine O'Neal     0.425        3             0.08293
# 8   2003-04      Dirk Nowitzki     0.003       10            0.079504
# 9   2003-04         Jason Kidd     0.014        8            0.058702
# 10  2003-04           Yao Ming     0.001       14            0.054219
# 11  2003-04        Baron Davis     0.003       10            0.038214
# 12  2003-04        Ben Wallace      0.02        7            0.014196
# 13  2003-04       Michael Redd     0.001       14           -0.050626
# 14  2003-04       LeBron James     0.009        9           -0.078457
# 15  2003-04    Carmelo Anthony     0.001       14           -0.098569
# 0   2002-03         Tim Duncan     0.808        1            0.410035
# 1   2002-03      Kevin Garnett     0.732        2            0.380474
# 2   2002-03      Tracy McGrady     0.359        4            0.361083
# 3   2002-03        Kobe Bryant     0.417        3            0.343845
# 4   2002-03      Dirk Nowitzki     0.036        7            0.325027
# 5   2002-03   Shaquille O'Neal     0.106        5            0.305961
# 6   2002-03         Jason Kidd     0.026        9            0.250402
# 7   2002-03         Steve Nash     0.001       11            0.189742
# 8   2002-03      Allen Iverson      0.07        6            0.162668
# 9   2002-03       Chris Webber     0.016       10            0.146522
# 10  2002-03        Paul Pierce     0.001       11            0.146001
# 11  2002-03     Jamal Mashburn     0.001       11            0.041823
# 12  2002-03        Ben Wallace     0.028        8           -0.002589
# 0   2001-02         Tim Duncan     0.757        1            0.456275
# 1   2001-02   Shaquille O'Neal     0.552        3            0.388658
# 2   2001-02      Kevin Garnett     0.013       12            0.259367
# 3   2001-02        Kobe Bryant     0.078        5            0.232101
# 4   2001-02      Tracy McGrady      0.31        4            0.207557
# 5   2001-02      Dirk Nowitzki     0.025        8            0.205833
# 6   2001-02        Paul Pierce     0.017       11             0.20428
# 7   2001-02       Chris Webber     0.029        7            0.192239
# 8   2001-02        Gary Payton     0.043        6            0.181749
# 9   2001-02         Jason Kidd     0.712        2            0.121094
# 10  2001-02         Steve Nash     0.004       14             0.11594
# 11  2001-02    Peja Stojaković     0.001       16            0.115016
# 12  2001-02      Allen Iverson     0.023        9            0.106098
# 13  2001-02        Elton Brand     0.001       16            0.070104
# 14  2001-02        Ben Wallace     0.019       10            0.030866
# 15  2001-02   Jerry Stackhouse     0.002       15            0.001743
# 16  2001-02         Mike Bibby     0.001       16           -0.098461
# 17  2001-02     Michael Jordan     0.013       13           -0.101667
# 0   2000-01   Shaquille O'Neal     0.466        3            0.429061
# 1   2000-01         Tim Duncan     0.569        2            0.281551
# 2   2000-01        Karl Malone     0.017        7            0.277325
# 3   2000-01      Allen Iverson     0.904        1            0.248794
# 4   2000-01       Chris Webber      0.42        4            0.244075
# 5   2000-01      Kevin Garnett     0.122        5            0.214659
# 6   2000-01      Tracy McGrady     0.052        6            0.208847
# 7   2000-01       Vince Carter     0.006       11            0.208508
# 8   2000-01          Ray Allen     0.006       11            0.198775
# 9   2000-01        Kobe Bryant     0.009        9             0.19679
# 10  2000-01     David Robinson     0.006       10            0.157595
# 11  2000-01      John Stockton     0.001       15            0.157049
# 12  2000-01         Jason Kidd     0.015        8            0.130068
# 13  2000-01   Jerry Stackhouse     0.002       14            0.118435
# 14  2000-01        Paul Pierce     0.004       13            0.056832
# 15  2000-01     Michael Finley     0.001       15            0.046103
# 16  2000-01      Anthony Mason     0.001       15            0.025651
# 0   1999-00   Shaquille O'Neal     0.998        1            0.553589
# 1   1999-00        Karl Malone     0.258        4            0.346182
# 2   1999-00         Tim Duncan     0.205        5            0.273847
# 3   1999-00      Kevin Garnett     0.337        2            0.266192
# 4   1999-00        Gary Payton     0.149        6            0.239853
# 5   1999-00    Alonzo Mourning     0.303        3            0.195918
# 6   1999-00        Kobe Bryant     0.002       12            0.184486
# 7   1999-00         Grant Hill     0.093        8            0.144192
# 8   1999-00       Chris Webber     0.079        9            0.142556
# 9   1999-00         Jason Kidd     0.021       11            0.106718
# 10  1999-00       Vince Carter     0.042       10            0.106334
# 11  1999-00      Allen Iverson     0.109        7            0.068256
# 12  1999-00  Darrell Armstrong     0.001       13            0.015519
# 13  1999-00      Reggie Miller     0.001       13            0.014638
# 14  1999-00     Michael Finley     0.001       13           -0.020669
# 15  1999-00         Jalen Rose     0.001       13           -0.022096
